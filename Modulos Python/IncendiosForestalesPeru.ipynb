# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
datos = pd.read_excel("./incendios.xlsx")
datos
# Out:
#     Year  Deforestation (ha)  Precipitation (mm)  Temperature (°C)  \
# 0   2010            8.000000             1000.00                15
# 1   2011          714.333333              950.00              1017
# 2   2011          714.333333             1254.75              1017
# 3   2019         2019.000000             2019.00              2019
# 4   2020          116.000000             1050.00              1017
# 5   2020          714.333333             1254.75              1017
# 6   2020          714.333333             1254.75              1017
# 7   2020          714.333333             1254.75              1017
# 8   2020          714.333333             1254.75              1017
# 9   2020          714.333333             1254.75              1017
# 10  2020          714.333333             1254.75              1017
# 11  2020          714.333333             1254.75              1017
# 12  2020          714.333333             1254.75              1017
# ...
