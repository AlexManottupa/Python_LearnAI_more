# %%
import nltk
nltk.download()
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
#Tokenizar texto

#leer texto desde html



from bs4 import BeautifulSoup

import urllib.request



url = 'https://librefinanciero.com/'

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}



req = urllib.request.Request(url, headers=headers)



try:

  response = urllib.request.urlopen(req)

  html = response.read()

  # Try using a different parser to see if the issue is specific to html5lib

  soup = BeautifulSoup(html, "html.parser") # Switch to html.parser or lxml

  text = soup.get_text(strip=True)

  print(text)

except Exception as e:

  print(f'An unexpected error occurred: {e}')
# Out:
# 🥇Alcanza la Libertad Financiera y Retírate🥇 - 【Libre Financiero】Skip to contentMenuInicio¡Empieza Aquí!Pasos a SeguirPaso 1: Calcula tu salario/hora REALPaso 2: Controla y Categoriza tus Ingresos y Gastos PersonalesPaso 3: Valora tus GastosPaso 4: Visualiza tu Estado Financiero PersonalPaso 5: Reduce tus Gastos y Aumenta tus IngresosPaso 6: Añade tus Inversiones a la fotoPaso 7: El “Punto de Corte” de la Independencia FinancieraEstrategias de InversiónInversión en Renta Fija & Renta VariableInversión en Préstamos P2P – CrowlendingInversión en Desarrollo PersonalBlogLibros RecomendadosSobre Mí¿Estás interesado en seguir gastando 10-12 horas diarias de tu energía en un trabajo hasta que un día consigas jubilarte a los 70 años en el mejor de los casos?Si la respuesta es SÍ, entonces este NO es tu blog, en caso contrario, bienvenido a la comunidadLibreFinancierodonde aprenderás qué es la libertad financiera y cómo ponerla en práctica.PERO… ¿QUÉ ES LA INDEPENDENCIA FINANCIERA?La independe
# ...

# %%
#Crea un tokens de palabras
#Tokens en palabras
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text, 'english' )
tokens = [maria.lower() for maria in tokens if maria.isalpha()] # para remover los signos de puntuacion
tokens
# Out:
# ['la',
#  'libertad',
#  'financiera',
#  'y',
#  'to',
#  'aquí',
#  'pasos',
#  'a',
#  'seguirpaso',
#  'calcula',
#  'tu',
#  'realpaso',
#  'controla',
#  'y',
#  'categoriza',
#  'tus',
#  'ingresos',
#  'y',
#  'gastos',
#  'personalespaso',
#  'valora',
#  'tus',
#  'gastospaso',
#  'visualiza',
#  'tu',
#  'estado',
#  'financiero',
#  'personalpaso',
#  'reduce',
#  'tus',
#  'gastos',
#  'y',
#  'aumenta',
#  'tus',
#  'ingresospaso',
#  'añade',
#  'tus',
#  'inversiones',
#  'a',
#  'la',
#  'fotopaso',
#  'el',
#  'punto',
#  'de',
#  'corte',
#  'de',
#  'la',
#  'independencia',
#  'financieraestrategias',
#  'de',
#  'inversióninversión',
#  'en',
#  'renta',
#  'fija',
#  'renta',
#  'variableinversión',
#  'en',
#  'préstamos',
#  'crowlendinginversión',
#  'en',
#  'desarrollo',
#  'personalbloglibros',
#  'recomendadossobre',
#  'interesado',
#  'en',
#  'seguir',
#  'gastando',
#  'horas',
#  'diarias',
#  'de',
#  'tu',
#  'energía',
#  'en',
#  'un',
# ...

# %%
freq = nltk.FreqDist(tokens)
for key, val in freq.items():
    {
        print(str(key) +' : ' +str(val))
    }
# Out:
# la : 505
# libertad : 77
# financiera : 92
# y : 301
# to : 3
# aquí : 7
# pasos : 14
# a : 357
# seguirpaso : 2
# calcula : 3
# tu : 189
# realpaso : 2
# controla : 2
# categoriza : 2
# tus : 138
# ingresos : 87
# gastos : 73
# personalespaso : 2
# valora : 2
# gastospaso : 2
# visualiza : 4
# estado : 16
# financiero : 14
# personalpaso : 2
# reduce : 2
# aumenta : 3
# ingresospaso : 2
# añade : 2
# inversiones : 23
# fotopaso : 2
# el : 400
# punto : 23
# de : 908
# corte : 3
# independencia : 28
# financieraestrategias : 2
# inversióninversión : 2
# en : 525
# renta : 18
# fija : 3
# variableinversión : 2
# préstamos : 5
# crowlendinginversión : 2
# desarrollo : 3
# personalbloglibros : 2
# recomendadossobre : 2
# interesado : 1
# seguir : 17
# gastando : 1
# horas : 10
# diarias : 2
# energía : 5
# un : 204
# trabajo : 36
# hasta : 24
# que : 732
# día : 26
# consigas : 3
# jubilarte : 1
# los : 167
# años : 34
# mejor : 30
# casos : 2
# si : 135
# respuesta : 7
# es : 320
# ...

# %%
#Visualizar tokens

sns.set()
freq.plot(30, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
#Eliminar palabras de parada
from nltk.corpus import stopwords
clean_tokens = tokens[:]
for token in tokens:
    if tokens in stopwords.words('spanish'):
        clean_tokens.remove(token)

# %%
clean_tokens
# Out:
# ['la',
#  'libertad',
#  'financiera',
#  'y',
#  'to',
#  'aquí',
#  'pasos',
#  'a',
#  'seguirpaso',
#  'calcula',
#  'tu',
#  'realpaso',
#  'controla',
#  'y',
#  'categoriza',
#  'tus',
#  'ingresos',
#  'y',
#  'gastos',
#  'personalespaso',
#  'valora',
#  'tus',
#  'gastospaso',
#  'visualiza',
#  'tu',
#  'estado',
#  'financiero',
#  'personalpaso',
#  'reduce',
#  'tus',
#  'gastos',
#  'y',
#  'aumenta',
#  'tus',
#  'ingresospaso',
#  'añade',
#  'tus',
#  'inversiones',
#  'a',
#  'la',
#  'fotopaso',
#  'el',
#  'punto',
#  'de',
#  'corte',
#  'de',
#  'la',
#  'independencia',
#  'financieraestrategias',
#  'de',
#  'inversióninversión',
#  'en',
#  'renta',
#  'fija',
#  'renta',
#  'variableinversión',
#  'en',
#  'préstamos',
#  'crowlendinginversión',
#  'en',
#  'desarrollo',
#  'personalbloglibros',
#  'recomendadossobre',
#  'interesado',
#  'en',
#  'seguir',
#  'gastando',
#  'horas',
#  'diarias',
#  'de',
#  'tu',
#  'energía',
#  'en',
#  'un',
# ...

# %%
#verificar frecuecia de palabras 
freq_clean = nltk.FreqDist(clean_tokens)
for key, val in freq_clean.items():
    print(str(key) + ' : ' + str(val))
# Out:
# la : 505
# libertad : 77
# financiera : 92
# y : 301
# to : 3
# aquí : 7
# pasos : 14
# a : 357
# seguirpaso : 2
# calcula : 3
# tu : 189
# realpaso : 2
# controla : 2
# categoriza : 2
# tus : 138
# ingresos : 87
# gastos : 73
# personalespaso : 2
# valora : 2
# gastospaso : 2
# visualiza : 4
# estado : 16
# financiero : 14
# personalpaso : 2
# reduce : 2
# aumenta : 3
# ingresospaso : 2
# añade : 2
# inversiones : 23
# fotopaso : 2
# el : 400
# punto : 23
# de : 908
# corte : 3
# independencia : 28
# financieraestrategias : 2
# inversióninversión : 2
# en : 525
# renta : 18
# fija : 3
# variableinversión : 2
# préstamos : 5
# crowlendinginversión : 2
# desarrollo : 3
# personalbloglibros : 2
# recomendadossobre : 2
# interesado : 1
# seguir : 17
# gastando : 1
# horas : 10
# diarias : 2
# energía : 5
# un : 204
# trabajo : 36
# hasta : 24
# que : 732
# día : 26
# consigas : 3
# jubilarte : 1
# los : 167
# años : 34
# mejor : 30
# casos : 2
# si : 135
# respuesta : 7
# es : 320
# ...

# %%
#Obtener antonimos
from nltk.corpus import wordnet
sinonimos = []

for syn in wordnet.synsets('investment'):
    for lemma in syn.lemmas():
        sinonimos.append(lemma.name())


sinonimos
# Out:
# ['investing',
#  'investment',
#  'investment',
#  'investment_funds',
#  'investment',
#  'investment',
#  'investment',
#  'investment',
#  'investiture']

# %%
#Obtener antonimos
from nltk.corpus import wordnet
antonimos = []

for syn in wordnet.synsets('good'):
    for l in syn.lemmas():
        if l.antonyms():
            antonimos.append(l.antonyms()[0].name())
                         

antonimos
# Out:
# ['evil', 'evilness', 'bad', 'badness', 'bad', 'evil', 'ill']

# %%
#Derivacion regresiva textos en español
from nltk.stem import SnowballStemmer

# %%
spanish_stemmer = SnowballStemmer('spanish')
print(spanish_stemmer.stem('trabajando'))
print(spanish_stemmer.stem('trabajo'))
print(spanish_stemmer.stem('trabajar'))
# Out:
# trabaj
# trabaj
# trabaj

# %%
#Reemplazar tokens

sinonimos = ['libertad', 'independencia']
for ind, sin in enumerate(sinonimos):
    clean_tokens_sin = [word.replace(sinonimos[ind], 'libertad') for word in clean_tokens]

# %%
#Recalcular frecuencia de palabras con sin agragdos
freq_clean_sin = nltk.FreqDist(clean_tokens_sin)
for key, val in freq_clean_sin.items():
    print(str(key) + ' : ' + str (val))
# Out:
# la : 505
# libertad : 105
# financiera : 92
# y : 301
# to : 3
# aquí : 7
# pasos : 14
# a : 357
# seguirpaso : 2
# calcula : 3
# tu : 189
# realpaso : 2
# controla : 2
# categoriza : 2
# tus : 138
# ingresos : 87
# gastos : 73
# personalespaso : 2
# valora : 2
# gastospaso : 2
# visualiza : 4
# estado : 16
# financiero : 14
# personalpaso : 2
# reduce : 2
# aumenta : 3
# ingresospaso : 2
# añade : 2
# inversiones : 23
# fotopaso : 2
# el : 400
# punto : 23
# de : 908
# corte : 3
# financieraestrategias : 2
# inversióninversión : 2
# en : 525
# renta : 18
# fija : 3
# variableinversión : 2
# préstamos : 5
# crowlendinginversión : 2
# desarrollo : 3
# personalbloglibros : 2
# recomendadossobre : 2
# interesado : 1
# seguir : 17
# gastando : 1
# horas : 10
# diarias : 2
# energía : 5
# un : 204
# trabajo : 36
# hasta : 24
# que : 732
# día : 26
# consigas : 3
# jubilarte : 1
# los : 167
# años : 34
# mejor : 30
# casos : 2
# si : 135
# respuesta : 7
# es : 320
# sí : 28
# ...

# %%
freq_clean_sin.plot(30, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
from nltk.stem import WordNetLemmatizer
lematizer = WordNetLemmatizer()
lematizer.lemmatize('working', pos="v")
# Out:
# 'work'

# %%
import spacy
nlp = spacy.blank('es')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 import spacy
#       2 nlp = spacy.blank('es')
#
# File c:\Users\alex_\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\__init__.py:6
#       3 from typing import Any, Dict, Iterable, Union
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File c:\Users\alex_\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\errors.py:3
#       1 import warnings
# ----> 3 from .compat import Literal
#       6 class ErrorsWithCodes(type):
#       7     def __getattribute__(self, code):
#
# File c:\Users\alex_\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\compat.py:39
# ...
